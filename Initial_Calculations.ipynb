# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
Weight = 2.722*9.81 #6lbs in Kg
rho = 1.223
Velocity = 11.176 # m/s or 25mi/hr
S = 0.3 # 300 square inches to meters squared
qinf = 1/2 * rho * Velocity**2
CL = Weight / (qinf * S)
CD = 0.05
Lift = Weight
Thrust = Weight/(CL/CD)
Power = Thrust * Velocity
LiftForce = 1/2 * rho * Velocity**2 * S * CL

# %%
print(f'Thrust is: {Thrust} Newtons\nPower is: {Power} Watts\nCl is: {CL}\nLift Force is: {LiftForce} Newtons')
# Out:
# Thrust is: 1.1456725473600002 Newtons
# Power is: 12.804036389295362 Watts
# Cl is: 1.1653774920910835
# Lift Force is: 26.70282 Newtons

# %%
NewS = np.linspace(0.21, 1.0, 100)
CL = Weight / (qinf * NewS)
plt.plot(NewS, CL)

# %%
NewLift = 1/2 * rho * Velocity**2 * NewS * CL
plt.plot(NewS, NewLift)
